# %% [markdown]
# # Importing Packages

# %%
import kaggle
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile
import ast

import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Gathering Data

# %%
# Ensure kaggle.json is in the correct location and configure the environment
os.environ['KAGGLE_CONFIG_DIR'] = os.path.expanduser("~/.kaggle")

# Download the dataset. This command downloads the dataset into the current directory
kaggle.api.dataset_download_files('rounakbanik/the-movies-dataset', path='./', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset

# %%
kaggle.api.authenticate()
kaggle.api.dataset_download_files('shivamb/netflix-shows', path='./', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows

# %% [markdown]
# # Cleaning Data

# %%
with ZipFile('Netflix Data.zip', 'r') as z:
    with z.open('netflix_titles.csv') as file:
        NT = pd.read_csv(file)

# %%
MMD = pd.read_csv('movies_metadata.csv')

# %%
#MMD.head(3)

# %%
#NT.head(3)

# %%
print(MMD.columns)
print(NT.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df = pd.merge(MMD, NT, left_on='original_title', right_on='title', how='inner')

# %%
df['genres']
# Out:
# 0       [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2       [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4       [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#                               ...
# 2479                  [{'id': 99, 'name': 'Documentary'}]
# 2480                  [{'id': 99, 'name': 'Documentary'}]
# 2481    [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2482    [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 2483    [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# Name: genres, Length: 2484, dtype: object

# %%
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: ast.literal_eval(x) if not pd.isna(x) and x != 'nan' else np.nan)
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: x['name'] if isinstance(x,dict) and 'name' in x else np.nan)

# %%
split_cols = ['production_companies','production_countries', 'genres', 'spoken_languages']

# %%
def process_columns(df, split_cols):
    for col in split_cols:
        df[col] = df[col].apply(lambda x: ast.literal_eval(x) if not pd.isna(x) and x != 'nan' else np.nan)
        df[col] = df[col].apply(lambda x: [d['name'] for d in x] if isinstance(x, list) else [])
        df[col] = df[col].apply(lambda x: '|'.join(x))
        temp_df = df[col].str.split('|', expand=True)
        temp_df.columns = [f"{col}_{i}" for i in range(temp_df.shape[1])]
        df = pd.concat([df, temp_df], axis=1)
        df.drop([col], inplace=True, axis=1)
    
    return df

# %%
df = process_columns(df, split_cols)

# %%
df['duration'] = df['duration'].str.extract('(\d+)').astype(float)

# %%
df.head(3)
# Out:
#    adult  belongs_to_collection    budget  \
# 0  False                    NaN  58000000
# 1  False                    NaN   2238813
# 2  False  James Bond Collection  58000000
#
#                                        homepage     id    imdb_id  \
# 0                                           NaN  11860  tt0114319
# 1                                           NaN   6620  tt0047437
# 2  http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
#
#   original_language original_title  \
# 0                en        Sabrina
# 1                en        Sabrina
# 2                en      GoldenEye
#
#                                             overview popularity  \
# 0  An ugly duckling having undergone a remarkable...   6.677277
# 1  Linus and David Larrabee are the two sons of a...   7.359741
# 2  James Bond must unmask the mysterious head of ...  14.686036
#
#                         poster_path release_date      revenue  runtime  \
# 0  /jQh15y5YB7bWz1NtffNZmRw0s9D.jpg   1995-12-15          0.0    127.0
# 1  /7ITDmatHa2yf5UTzjwaKAvf3Xr6.jpg   1954-09-28   10000000.0    113.0
# 2  /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg   1995-11-16  352194034.0    130.0
#
#      status                                            tagline    title_x  \
# 0  Released  You are cordially invited to the most surprisi...    Sabrina
# 1  Released  ...the chauffeur's daughter who learned her st...    Sabrina
# 2  Released               No limits. No fears. No substitutes.  GoldenEye
#
#    video  vote_average  vote_count show_id   type    title_y         director  \
# 0  False           6.2       141.0   s4375  Movie    Sabrina     Rocky Soraya
# 1  False           7.4       284.0   s4375  Movie    Sabrina     Rocky Soraya
# 2  False           6.6      1194.0   s6867  Movie  GoldenEye  Martin Campbell
#
#                                                 cast  \
# 0  Luna Maya, Christian Sugiono, Sara Wijayanto, ...
# 1  Luna Maya, Christian Sugiono, Sara Wijayanto, ...
# 2  Pierce Brosnan, Sean Bean, Izabella Scorupco, ...
#
#                          country         date_added  release_year rating  \
# 0                      Indonesia  November 20, 2018          2018  TV-MA
# 1                      Indonesia  November 20, 2018          2018  TV-MA
# 2  United Kingdom, United States  December 31, 2019          1995  PG-13
#
#    duration                            listed_in  \
# 0     114.0  Horror Movies, International Movies
# 1     114.0  Horror Movies, International Movies
# 2     130.0                   Action & Adventure
#
#                                          description production_companies_0  \
# 0  A toy manufacturer and his wife are terrorized...     Paramount Pictures
# 1  A toy manufacturer and his wife are terrorized...     Paramount Pictures
# 2  Pierce Brosnan takes his first turn as debonai...         United Artists
#
#     production_companies_1 production_companies_2 production_companies_3  \
# 0  Scott Rudin Productions     Mirage Enterprises  Sandollar Productions
# 1                     None                   None                   None
# 2          Eon Productions                   None                   None
#
#         production_companies_4 production_companies_5  \
# 0  Constellation Entertainment              Worldwide
# 1                         None                   None
# 2                         None                   None
#
#           production_companies_6 production_companies_7  \
# 0  Mont Blanc Entertainment GmbH                   None
# 1                           None                   None
# 2                           None                   None
#
#   production_companies_8 production_companies_9 production_companies_10  \
# 0                   None                   None                    None
# 1                   None                   None                    None
# 2                   None                   None                    None
#
#   production_companies_11 production_companies_12 production_companies_13  \
# 0                    None                    None                    None
# 1                    None                    None                    None
# 2                    None                    None                    None
#
#   production_companies_14 production_companies_15 production_companies_16  \
# 0                    None                    None                    None
# 1                    None                    None                    None
# 2                    None                    None                    None
#
#   production_companies_17    production_countries_0    production_countries_1  \
# 0                    None                   Germany  United States of America
# 1                    None  United States of America                      None
# 2                    None            United Kingdom  United States of America
#
#   production_countries_2 production_countries_3 production_countries_4  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 2                   None                   None                   None
#
#   production_countries_5 production_countries_6 production_countries_7  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 2                   None                   None                   None
#
#   production_countries_8 production_countries_9   genres_0 genres_1  genres_2  \
# 0                   None                   None     Comedy  Romance      None
# 1                   None                   None     Comedy    Drama   Romance
# 2                   None                   None  Adventure   Action  Thriller
#
#   genres_3 genres_4 genres_5 genres_6 spoken_languages_0 spoken_languages_1  \
# 0     None     None     None     None           Français            English
# 1     None     None     None     None            English           Italiano
# 2     None     None     None     None            English            Pусский
#
#   spoken_languages_2 spoken_languages_3 spoken_languages_4 spoken_languages_5  \
# 0               None               None               None               None
# 1               None               None               None               None
# 2            Español               None               None               None
#
#   spoken_languages_6 spoken_languages_7 spoken_languages_8
# 0               None               None               None
# 1               None               None               None
# 2               None               None               None

# %%
new_names = {old_name: f"prod_comp_{old_name.split('_')[-1]}" for old_name in df.columns if 'production_companies_' in old_name}
df.rename(columns=new_names, inplace=True)

# %%
new_names = {old_name: f"lang{old_name.split('_')[-1]}" for old_name in df.columns if 'spoken_languages' in old_name}
df.rename(columns=new_names, inplace=True)

# %%
new_names = {old_name: f"g{old_name.split('_')[-1]}" for old_name in df.columns if 'genre' in old_name}
df.rename(columns=new_names, inplace=True)
# Out:
#    adult  belongs_to_collection    budget  \
# 0  False                    NaN  58000000
# 1  False                    NaN   2238813
# 2  False  James Bond Collection  58000000
#
#                                        homepage     id    imdb_id  \
# 0                                           NaN  11860  tt0114319
# 1                                           NaN   6620  tt0047437
# 2  http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
#
#   original_language original_title  \
# 0                en        Sabrina
# 1                en        Sabrina
# 2                en      GoldenEye
#
#                                             overview popularity  \
# 0  An ugly duckling having undergone a remarkable...   6.677277
# 1  Linus and David Larrabee are the two sons of a...   7.359741
# 2  James Bond must unmask the mysterious head of ...  14.686036
#
#                         poster_path release_date      revenue  runtime  \
# 0  /jQh15y5YB7bWz1NtffNZmRw0s9D.jpg   1995-12-15          0.0    127.0
# 1  /7ITDmatHa2yf5UTzjwaKAvf3Xr6.jpg   1954-09-28   10000000.0    113.0
# 2  /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg   1995-11-16  352194034.0    130.0
#
#      status                                            tagline    title_x  \
# 0  Released  You are cordially invited to the most surprisi...    Sabrina
# 1  Released  ...the chauffeur's daughter who learned her st...    Sabrina
# 2  Released               No limits. No fears. No substitutes.  GoldenEye
#
#    video  vote_average  vote_count show_id   type    title_y         director  \
# 0  False           6.2       141.0   s4375  Movie    Sabrina     Rocky Soraya
# 1  False           7.4       284.0   s4375  Movie    Sabrina     Rocky Soraya
# 2  False           6.6      1194.0   s6867  Movie  GoldenEye  Martin Campbell
#
#                                                 cast  \
# 0  Luna Maya, Christian Sugiono, Sara Wijayanto, ...
# 1  Luna Maya, Christian Sugiono, Sara Wijayanto, ...
# 2  Pierce Brosnan, Sean Bean, Izabella Scorupco, ...
#
#                          country         date_added  release_year rating  \
# 0                      Indonesia  November 20, 2018          2018  TV-MA
# 1                      Indonesia  November 20, 2018          2018  TV-MA
# 2  United Kingdom, United States  December 31, 2019          1995  PG-13
#
#    duration                            listed_in  \
# 0     114.0  Horror Movies, International Movies
# 1     114.0  Horror Movies, International Movies
# 2     130.0                   Action & Adventure
#
#                                          description         prod_comp_0  \
# 0  A toy manufacturer and his wife are terrorized...  Paramount Pictures
# 1  A toy manufacturer and his wife are terrorized...  Paramount Pictures
# 2  Pierce Brosnan takes his first turn as debonai...      United Artists
#
#                prod_comp_1         prod_comp_2            prod_comp_3  \
# 0  Scott Rudin Productions  Mirage Enterprises  Sandollar Productions
# 1                     None                None                   None
# 2          Eon Productions                None                   None
#
#                    prod_comp_4 prod_comp_5                    prod_comp_6  \
# 0  Constellation Entertainment   Worldwide  Mont Blanc Entertainment GmbH
# 1                         None        None                           None
# 2                         None        None                           None
#
#   prod_comp_7 prod_comp_8 prod_comp_9 prod_comp_10 prod_comp_11 prod_comp_12  \
# 0        None        None        None         None         None         None
# 1        None        None        None         None         None         None
# 2        None        None        None         None         None         None
#
#   prod_comp_13 prod_comp_14 prod_comp_15 prod_comp_16 prod_comp_17  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
#
#      production_countries_0    production_countries_1 production_countries_2  \
# 0                   Germany  United States of America                   None
# 1  United States of America                      None                   None
# 2            United Kingdom  United States of America                   None
#
#   production_countries_3 production_countries_4 production_countries_5  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 2                   None                   None                   None
#
#   production_countries_6 production_countries_7 production_countries_8  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 2                   None                   None                   None
#
#   production_countries_9   genres_0 genres_1  genres_2 genres_3 genres_4  \
# 0                   None     Comedy  Romance      None     None     None
# 1                   None     Comedy    Drama   Romance     None     None
# 2                   None  Adventure   Action  Thriller     None     None
#
#   genres_5 genres_6     lang0     lang1    lang2 lang3 lang4 lang5 lang6  \
# 0     None     None  Français   English     None  None  None  None  None
# 1     None     None   English  Italiano     None  None  None  None  None
# 2     None     None   English   Pусский  Español  None  None  None  None
#
#   lang7 lang8
# 0  None  None
# 1  None  None
# 2  None  None

# %%
df.rename(columns={0:'g1', 1:'g2', 2:'g3', 3:'g4', 4:'g5', 5:'g5', 6:'g6'}, inplace=True)
